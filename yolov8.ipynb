# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")  # build a new model from scratch
# model = YOLO("/Users/d1ffic00lt/Documents/projects/ai-animals-tracking/yolov8n.pt")  # load a pretrained model (recommended for training)

# model.train(data="coco8.yaml", epochs=3)  # train the model
# metrics = model.val()  # evaluate model performance on the validation set
# results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
# path = model.export(format="onnx")  # export the model to ONNX format

# %%
import torch

model.model.load_state_dict(torch.load("./yolov8n.pt")["model"].state_dict())
# Out:
# <All keys matched successfully>

# %%
result = model.predict("./test.jpg")
# Out:
# image 1/1 /Users/d1ffic00lt/Documents/projects/ai-animals-tracking/test.jpg: 480x640 6 0s, 1 33, 95.6ms
# Speed: 3.4ms preprocess, 95.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
import cv2

vid = cv2.VideoCapture(0)

key = 0
while key != 27:
    ret, frame = vid.read()
    if ret:
        cv2.imshow("Frame", frame)
        preds = model.predict(frame)
        for r in preds:
            im_array = r.plot()  # plot a BGR numpy array of predictions
            cv2.imshow("preds", im_array)
    key = cv2.waitKey(100)
# Out:
# 2024-06-28 18:18:54.047 Python[57836:3184754] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 2024-06-28 18:18:55.217 Python[57836:3184754] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/64/q9vthv094_591jd1jlz91_x00000gn/T/org.python.python.savedState
# 0: 384x640 1 0, 1 27, 133.7ms
# Speed: 23.9ms preprocess, 133.7ms inference, 14.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 95.6ms
# Speed: 1.5ms preprocess, 95.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 81.1ms
# Speed: 1.4ms preprocess, 81.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.1ms
# Speed: 1.4ms preprocess, 69.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.1ms
# Speed: 1.3ms preprocess, 63.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 60.6ms
# Speed: 1.5ms preprocess, 60.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.0ms
# Speed: 1.4ms preprocess, 68.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.3ms
# Speed: 1.7ms preprocess, 66.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.2ms
# Speed: 1.8ms preprocess, 64.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.4ms
# Speed: 2.0ms preprocess, 65.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.0ms
# Speed: 1.7ms preprocess, 67.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.1ms
# Speed: 2.4ms preprocess, 67.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.5ms
# Speed: 2.5ms preprocess, 66.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.5ms
# Speed: 1.7ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.7ms
# Speed: 1.7ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.8ms
# Speed: 1.6ms preprocess, 66.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.5ms
# Speed: 1.9ms preprocess, 65.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 72.4ms
# Speed: 2.0ms preprocess, 72.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.9ms
# Speed: 1.6ms preprocess, 62.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 72.2ms
# Speed: 1.1ms preprocess, 72.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.6ms
# Speed: 1.7ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 72.6ms
# Speed: 1.6ms preprocess, 72.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 61.8ms
# Speed: 1.9ms preprocess, 61.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 70.5ms
# Speed: 2.2ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.3ms
# Speed: 2.1ms preprocess, 66.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.8ms
# Speed: 1.5ms preprocess, 67.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 60.9ms
# Speed: 1.6ms preprocess, 60.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.1ms
# Speed: 2.0ms preprocess, 65.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.6ms
# Speed: 1.6ms preprocess, 64.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 61.2ms
# Speed: 1.5ms preprocess, 61.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 73.5ms
# Speed: 1.8ms preprocess, 73.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.8ms
# Speed: 1.5ms preprocess, 63.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 77.5ms
# Speed: 2.3ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 73.9ms
# Speed: 1.7ms preprocess, 73.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 123.8ms
# Speed: 1.8ms preprocess, 123.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 2024-06-28 18:19:03.411 Python[57836:3184754] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# 0: 384x640 1 0, 1 27, 88.2ms
# Speed: 2.5ms preprocess, 88.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 77.4ms
# Speed: 1.7ms preprocess, 77.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 74.0ms
# Speed: 1.8ms preprocess, 74.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.9ms
# Speed: 2.1ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 87.2ms
# Speed: 2.7ms preprocess, 87.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 71.7ms
# Speed: 2.1ms preprocess, 71.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 59.8ms
# Speed: 2.3ms preprocess, 59.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.7ms
# Speed: 2.0ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 61.1ms
# Speed: 1.6ms preprocess, 61.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.4ms
# Speed: 2.2ms preprocess, 69.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 83.9ms
# Speed: 2.3ms preprocess, 83.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 76.3ms
# Speed: 1.8ms preprocess, 76.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 73.1ms
# Speed: 2.4ms preprocess, 73.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.2ms
# Speed: 2.2ms preprocess, 66.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.3ms
# Speed: 2.3ms preprocess, 66.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.3ms
# Speed: 2.4ms preprocess, 68.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 81.5ms
# Speed: 2.0ms preprocess, 81.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 75.3ms
# Speed: 1.5ms preprocess, 75.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 57.4ms
# Speed: 1.5ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 61.5ms
# Speed: 1.7ms preprocess, 61.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 72.4ms
# Speed: 2.4ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 70.0ms
# Speed: 2.4ms preprocess, 70.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.5ms
# Speed: 2.1ms preprocess, 69.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 76.6ms
# Speed: 2.4ms preprocess, 76.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.0ms
# Speed: 1.9ms preprocess, 66.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.1ms
# Speed: 1.5ms preprocess, 64.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 71.3ms
# Speed: 2.1ms preprocess, 71.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.6ms
# Speed: 1.8ms preprocess, 68.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.3ms
# Speed: 1.7ms preprocess, 68.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 71.9ms
# Speed: 1.9ms preprocess, 71.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.7ms
# Speed: 2.4ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.7ms
# Speed: 2.7ms preprocess, 66.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.7ms
# Speed: 1.7ms preprocess, 68.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.0ms
# Speed: 2.2ms preprocess, 69.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 70.8ms
# Speed: 1.8ms preprocess, 70.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.9ms
# Speed: 1.7ms preprocess, 64.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.9ms
# Speed: 1.8ms preprocess, 67.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.9ms
# Speed: 1.8ms preprocess, 69.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 78.5ms
# Speed: 1.4ms preprocess, 78.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 73.8ms
# Speed: 1.7ms preprocess, 73.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 71.8ms
# Speed: 1.4ms preprocess, 71.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.4ms
# Speed: 2.4ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 73.2ms
# Speed: 1.6ms preprocess, 73.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.9ms
# Speed: 1.8ms preprocess, 64.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 70.0ms
# Speed: 1.8ms preprocess, 70.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 59.6ms
# Speed: 1.1ms preprocess, 59.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 71.2ms
# Speed: 2.3ms preprocess, 71.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.2ms
# Speed: 2.1ms preprocess, 67.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.1ms
# Speed: 1.8ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.8ms
# Speed: 2.2ms preprocess, 63.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.4ms
# Speed: 1.9ms preprocess, 62.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.3ms
# Speed: 1.8ms preprocess, 66.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.5ms
# Speed: 1.4ms preprocess, 66.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.1ms
# Speed: 2.1ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.2ms
# Speed: 1.9ms preprocess, 66.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.6ms
# Speed: 1.6ms preprocess, 68.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.1ms
# Speed: 1.5ms preprocess, 66.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.1ms
# Speed: 1.9ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 82.7ms
# Speed: 1.9ms preprocess, 82.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 94.3ms
# Speed: 1.1ms preprocess, 94.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.6ms
# Speed: 1.1ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 72.7ms
# Speed: 1.7ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.3ms
# Speed: 1.8ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.2ms
# Speed: 1.7ms preprocess, 68.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.2ms
# Speed: 2.3ms preprocess, 69.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 72.4ms
# Speed: 1.7ms preprocess, 72.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 70.8ms
# Speed: 1.5ms preprocess, 70.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 90.6ms
# Speed: 1.5ms preprocess, 90.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 73.9ms
# Speed: 1.5ms preprocess, 73.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.3ms
# Speed: 1.6ms preprocess, 67.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.6ms
# Speed: 1.6ms preprocess, 66.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.3ms
# Speed: 1.7ms preprocess, 68.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.5ms
# Speed: 1.7ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.5ms
# Speed: 1.9ms preprocess, 64.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.5ms
# Speed: 1.8ms preprocess, 65.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.0ms
# Speed: 2.3ms preprocess, 63.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 67.4ms
# Speed: 2.0ms preprocess, 67.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.6ms
# Speed: 1.6ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 64.0ms
# Speed: 2.3ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 72.3ms
# Speed: 2.2ms preprocess, 72.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 62.2ms
# Speed: 1.8ms preprocess, 62.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 76.7ms
# Speed: 1.9ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 71.0ms
# Speed: 2.1ms preprocess, 71.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 83.9ms
# Speed: 1.7ms preprocess, 83.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 72.5ms
# Speed: 1.8ms preprocess, 72.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.7ms
# Speed: 2.5ms preprocess, 65.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 81.1ms
# Speed: 1.9ms preprocess, 81.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 81.2ms
# Speed: 1.8ms preprocess, 81.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 83.5ms
# Speed: 2.9ms preprocess, 83.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 87.1ms
# Speed: 1.5ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 76.1ms
# Speed: 1.7ms preprocess, 76.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 80.8ms
# Speed: 1.5ms preprocess, 80.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.1ms
# Speed: 2.1ms preprocess, 66.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 92.7ms
# Speed: 1.8ms preprocess, 92.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.1ms
# Speed: 1.5ms preprocess, 65.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 73.5ms
# Speed: 2.2ms preprocess, 73.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 69.3ms
# Speed: 2.3ms preprocess, 69.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 92.1ms
# Speed: 1.6ms preprocess, 92.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 75.5ms
# Speed: 1.6ms preprocess, 75.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 72.2ms
# Speed: 3.2ms preprocess, 72.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.7ms
# Speed: 1.6ms preprocess, 66.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 80.4ms
# Speed: 2.4ms preprocess, 80.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 71.9ms
# Speed: 1.8ms preprocess, 71.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 67.4ms
# Speed: 1.6ms preprocess, 67.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 75.7ms
# Speed: 1.9ms preprocess, 75.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 67.5ms
# Speed: 1.7ms preprocess, 67.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.6ms
# Speed: 1.3ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.8ms
# Speed: 1.8ms preprocess, 69.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 78.3ms
# Speed: 1.8ms preprocess, 78.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 71.0ms
# Speed: 1.5ms preprocess, 71.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 70.2ms
# Speed: 1.9ms preprocess, 70.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 66.8ms
# Speed: 1.9ms preprocess, 66.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 66.8ms
# Speed: 2.2ms preprocess, 66.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.6ms
# Speed: 1.8ms preprocess, 64.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 62.2ms
# Speed: 1.7ms preprocess, 62.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.4ms
# Speed: 1.9ms preprocess, 64.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.4ms
# Speed: 1.7ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.8ms
# Speed: 2.1ms preprocess, 64.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 66.4ms
# Speed: 1.7ms preprocess, 66.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.4ms
# Speed: 2.0ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 67.9ms
# Speed: 2.7ms preprocess, 67.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 66.0ms
# Speed: 1.8ms preprocess, 66.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 70.7ms
# Speed: 2.4ms preprocess, 70.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.2ms
# Speed: 1.6ms preprocess, 65.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.2ms
# Speed: 1.5ms preprocess, 68.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.3ms
# Speed: 1.4ms preprocess, 65.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.8ms
# Speed: 2.1ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.5ms
# Speed: 1.5ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 69.4ms
# Speed: 2.2ms preprocess, 69.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.5ms
# Speed: 1.8ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.4ms
# Speed: 2.1ms preprocess, 64.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 71.0ms
# Speed: 1.7ms preprocess, 71.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 64.1ms
# Speed: 2.2ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 65.4ms
# Speed: 1.8ms preprocess, 65.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 63.7ms
# Speed: 1.6ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 68.1ms
# Speed: 2.1ms preprocess, 68.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 59.2ms
# Speed: 1.3ms preprocess, 59.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 67.6ms
# Speed: 2.1ms preprocess, 67.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 0, 1 27, 57.1ms
# Speed: 1.8ms preprocess, 57.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
